# %%
import pandas as pd
import numpy as np
import json
pd.set_option('max_columns', 50)

# %%
optd_por = pd.read_csv('optd_por_public.csv', sep='^')

# %%
optd_por.head()
# Out:
#   iata_code icao_code faa_code is_geonames  geoname_id  envelope_id  \
# 0       AAA      NTGA      NaN           Y     6947726          NaN
# 1       AAA       NaN      NaN           Y     4034700          NaN
# 2       AAB      YARY      NaN           Y     7730796          NaN
# 3       AAC      HEAR      NaN           Y     6297289          NaN
# 4       AAC       NaN      NaN           Y      361546          NaN
#
#                              name                       asciiname   latitude  \
# 0                    Anaa Airport                    Anaa Airport -17.352606
# 1                            Anaa                            Anaa -17.416670
# 2                Arrabury Airport                Arrabury Airport -26.750000
# 3  El Arish International Airport  El Arish International Airport  31.073330
# 4                           Arish                           Arish  31.131590
#
#     longitude fclass fcode  page_rank date_from date_until comment  \
# ...

# %%
optd_por.describe()
# Out:
#            geoname_id  envelope_id      latitude     longitude    page_rank  \
# count    17976.000000   421.000000  17961.000000  17961.000000  5241.000000
# mean   4796608.182187     1.004751     23.991553     -3.289491     0.043934
# std    2598087.569958     0.068842     28.806534     91.185882     0.080038
# min          0.000000     1.000000    -62.190830   -179.955370     0.003659
# 25%    2639195.500000     1.000000      0.830180    -81.486356     0.013420
# 50%    5366660.500000     1.000000     33.195870      1.866670     0.020277
# 75%    6620051.000000     1.000000     46.479861     65.393610     0.037522
# max    9176521.000000     2.000000     82.517780    179.998970     1.000000
#
#             population    elevation       gtopo30    gmt_offset    dst_offset  \
# count     16984.000000  6500.000000  16982.000000  16992.000000  16992.000000
# mean      86323.706959   337.151231    145.144800      0.277940      0.678952
# ...

# %%
optd_por_city = optd_por['city_code_list'].map(lambda x: x.split(',')[0])

# %%
optd_por_city.head()
# Out:
# 0    AAA
# 1    AAA
# 2    AAB
# 3    AAC
# 4    AAC
# Name: city_code_list, dtype: object

# %%
optd_por[optd_por_city == 'FRA'].head()
# Out:
#       iata_code icao_code faa_code is_geonames  geoname_id  envelope_id  \
# 4235        FRA      EDDF      NaN           Y     6290293          NaN
# 4236        FRA       NaN      NaN           Y     2925533          NaN
# 5181        HHN      EDFH      NaN           Y     6296512          NaN
# 11272       QGV       NaN      NaN           N           0          NaN
# 17719       ZRB       NaN      NaN           N           0          NaN
#
#                                  name                       asciiname  \
# 4235                Frankfurt Airport               Frankfurt Airport
# 4236                Frankfurt am Main               Frankfurt am Main
# 5181           Frankfurt-Hahn Airport          Frankfurt-Hahn Airport
# 11272  Frankfurt DE Neu Isenburg Rail  Frankfurt DE Neu Isenburg Rail
# 17719  Frankfurt DE Hbf Railway Stati  Frankfurt DE Hbf Railway Stati
#
#         latitude  longitude fclass  fcode  page_rank date_from date_until  \
# ...
