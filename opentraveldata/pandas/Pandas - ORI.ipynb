# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
pd.set_option('max_columns', 50)

# %%
ori_por = pd.read_csv('ori_por_public.csv', sep='^')

# %%
ori_por.head()
# Out:
#   iata_code icao_code faa_code is_geonames  geoname_id  envelope_id  \
# 0       AAA      NTGA      NaN           Y     6947726          NaN
# 1       AAA      ZZZZ      NaN           Y     4034700          NaN
# 2       AAB      YARY      NaN           Y     7730796          NaN
# 3       AAC      HEAR      NaN           Y     6297289          NaN
# 4       AAC      ZZZZ      NaN           Y      361546          NaN
#
#                              name                       asciiname   latitude  \
# 0                    Anaa Airport                    Anaa Airport -17.352606
# 1                            Anaa                            Anaa -17.416670
# 2                Arrabury Airport                Arrabury Airport -26.750000
# 3  El Arish International Airport  El Arish International Airport  31.073330
# 4                           Arish                           Arish  31.131590
#
#     longitude fclass fcode  page_rank date_from date_until comment  \
# ...

# %%
ori_por.describe()
# Out:
#            geoname_id  envelope_id      latitude     longitude    page_rank  \
# count    17354.000000   293.000000  17339.000000  17339.000000  3246.000000
# mean   4764295.572145     1.006826     24.004924     -3.392346     0.041582
# std    2619395.289781     0.082478     28.917882     91.051896     0.077744
# min          0.000000     1.000000    -62.190830   -179.955370     0.003284
# 25%    2572483.250000     1.000000      0.635209    -81.586594     0.011663
# 50%    5370805.500000     1.000000     33.511306      1.833330     0.016831
# 75%    6453425.750000     1.000000     46.530000     63.352981     0.033500
# max    8629457.000000     2.000000     82.517780    179.998970     1.000000
#
#             population    elevation       gtopo30    gmt_offset    dst_offset  \
# count     16203.000000  6289.000000  16202.000000  16203.000000  16203.000000
# mean      77096.725915   340.289076    137.707197      0.298108      0.700133
# ...

# %%
ori_por_city = ori_por['city_code_list'].map(lambda x: x.split(',')[0])

# %%
ori_por_city.head()
# Out:
# 0    AAA
# 1    AAA
# 2    AAB
# 3    AAC
# 4    AAC
# Name: city_code_list, dtype: object

# %%
ori_por[ori_por_city == 'FRA'].head()
# Out:
#       iata_code icao_code faa_code is_geonames  geoname_id  envelope_id  \
# 4067        FRA      EDDF      NaN           Y     6290293          NaN
# 4068        FRA      ZZZZ      NaN           Y     2925533          NaN
# 4974        HHN      EDFH      NaN           Y     6296512          NaN
# 10862       QGV      ZZZZ      NaN           N           0          NaN
# 17100       ZRB      ZZZZ      NaN           N           0          NaN
#
#                                  name                       asciiname  \
# 4067                Frankfurt Airport               Frankfurt Airport
# 4068                Frankfurt am Main               Frankfurt am Main
# 4974           Frankfurt-Hahn Airport          Frankfurt-Hahn Airport
# 10862  Frankfurt DE Neu Isenburg Rail  Frankfurt DE Neu Isenburg Rail
# 17100  Frankfurt DE Hbf Railway Stati  Frankfurt DE Hbf Railway Stati
#
#         latitude  longitude fclass fcode  page_rank date_from date_until  \
# ...
